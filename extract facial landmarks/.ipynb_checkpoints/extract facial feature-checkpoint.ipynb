# %%
from facenet_pytorch import MTCNN, InceptionResnetV1
import torch
from PIL import Image
import numpy as np
import os
from itertools import combinations

# MTCNN으로 얼굴 검출, InceptionResnetV1로 임베딩 생성
mtcnn = MTCNN(keep_all=True)
resnet = InceptionResnetV1(pretrained='vggface2').eval()

# 이미지 폴더 경로 설정
base_folder = 'output_frames'

# 이미지 파일 이름 추출 (가정: 모든 폴더에 동일한 이름의 이미지 파일이 있음)
sample_folder = os.listdir(base_folder)[0]
image_files = os.listdir(os.path.join(base_folder, sample_folder))

# 모든 이미지 파일에 대해 유사도 계산 및 가장 유사한 이미지 쌍 찾기
for img_file in image_files:
    embeddings = []
    folder_names = []

    # 각 폴더의 동일한 이름을 가진 이미지에 대해 임베딩 생성
    for folder_name in sorted(os.listdir(base_folder)):
        img_path = os.path.join(base_folder, folder_name, img_file)
        img = Image.open(img_path)

        # 얼굴 검출 및 임베딩 생성
        boxes, probs = mtcnn.detect(img)
        if boxes is not None:
            faces = mtcnn(img)
            # 여러 얼굴에 대한 처리: 예를 들어, 첫 번째 얼굴만 사용
            if faces is not None:
                if faces.ndim == 3:
                    faces = faces.unsqueeze(0)  # 단일 얼굴의 경우 차원 수정
                emb = resnet(faces[0].unsqueeze(0))  # 첫 번째 얼굴에 대한 임베딩
                embeddings.append(emb.detach().numpy()[0])
                folder_names.append(folder_name)

    if len(embeddings) > 1:  # 임베딩이 2개 이상일 때만 유사도 계산
        # 임베딩 간의 유사도 계산
        max_similarity = -1
        most_similar_pair = None
        for (i, j) in combinations(range(len(embeddings)), 2):
            similarity = np.dot(embeddings[i], embeddings[j]) / (np.linalg.norm(embeddings[i]) * np.linalg.norm(embeddings[j]))
            if similarity > max_similarity:
                max_similarity = similarity
                most_similar_pair = (folder_names[i], folder_names[j])

        # 가장 유사한 이미지 쌍 출력
        if most_similar_pair:
            print(f"Image {img_file}: Most similar pair is between {most_similar_pair[0]} and {most_similar_pair[1]} with similarity {max_similarity:.2f}")
# Out:
# Image frame_00046.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.31
# Image frame_00076.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.17
# Image frame_00077.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.13
# Image frame_00081.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.20
# Image frame_00100.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.14
# Image frame_00101.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.15
# Image frame_00102.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.17
# Image frame_00103.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.25
# Image frame_00104.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.12
# Image frame_00105.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.17
# Image frame_00106.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.20
# Image frame_00107.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.25
# Image frame_00108.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.25
# Image frame_00109.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.12
# Image frame_00110.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.22
# Image frame_00111.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.12
# Image frame_00112.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.10
# Image frame_00113.jpg: Most similar pair is between 1_frames and 2_frames with similarity -0.04
# Image frame_00114.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.11
# Image frame_00115.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.18
# Image frame_00116.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.24
# Image frame_00117.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.16
# Image frame_00118.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.07
# Image frame_00119.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.15
# Image frame_00120.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.19
# Image frame_00121.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.00
# Image frame_00122.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.10
# Image frame_00123.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.15
# Image frame_00124.jpg: Most similar pair is between 1_frames and 2_frames with similarity -0.04
# Image frame_00125.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.24
# Image frame_00126.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.25
# Image frame_00127.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.13
# Image frame_00128.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.12
# Image frame_00129.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.19
# Image frame_00130.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.26
# Image frame_00131.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.15
# Image frame_00132.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.01
# Image frame_00133.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.24
# Image frame_00134.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.21
# Image frame_00135.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.10
# Image frame_00136.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.12
# Image frame_00137.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.17
# Image frame_00138.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.21
# Image frame_00139.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.18
# Image frame_00140.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.15
# Image frame_00141.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.24
# Image frame_00142.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.13
# Image frame_00143.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.13
# Image frame_00144.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.12
# Image frame_00145.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.24
# Image frame_00146.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.13
# Image frame_00147.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.25
# Image frame_00148.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.22
# Image frame_00149.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.20
# Image frame_00150.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.15
# Image frame_00151.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.23
# Image frame_00152.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.18
# Image frame_00153.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.20
# Image frame_00154.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.13
# Image frame_00155.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.09
# Image frame_00156.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.12
# Image frame_00157.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.17
# Image frame_00158.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.18
# Image frame_00159.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.05
# Image frame_00160.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.04
# Image frame_00161.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.13
# Image frame_00162.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.14
# Image frame_00163.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.19
# Image frame_00164.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.14
# Image frame_00165.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.08
# Image frame_00166.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0
jpg: Most similar pair is between 2_frames and 3_frames with similarity 0.77
# Image frame_03440.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.67
# Image frame_03441.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.70
# Image frame_03442.jpg: Most similar pair is between 2_frames and 3_frames with similarity 0.61
# Image frame_03443.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.65
# Image frame_03444.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.66
# Image frame_03445.jpg: Most similar pair is between 2_frames and 3_frames with similarity 0.14
# Image frame_03446.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.63
# Image frame_03447.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.48
# Image frame_03448.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.42
# Image frame_03449.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.71
# Image frame_03450.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.41
# Image frame_03451.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.48
# Image frame_03452.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.59
# Image frame_03453.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.42
# Image frame_03454.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.65
# Image frame_03455.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.67
# Image frame_03456.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.31
# Image frame_03457.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.44
# Image frame_03458.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.55
# Image frame_03459.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.62
# Image frame_03460.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.50
# Image frame_03461.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.52
# Image frame_03462.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.53
# Image frame_03463.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.55
# Image frame_03464.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.52
# Image frame_03465.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.45
# Image frame_03466.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.31
# Image frame_03467.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.25
# Image frame_03468.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.31
# Image frame_03469.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.39
# Image frame_03470.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.60
# Image frame_03471.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.61
# Image frame_03472.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.61
# Image frame_03473.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.40
# Image frame_03474.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.10
# Image frame_03475.jpg: Most similar pair is between 2_frames and 3_frames with similarity 0.24
# Image frame_03476.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.32
# Image frame_03477.jpg: Most similar pair is between 2_frames and 3_frames with similarity 0.32
# Image frame_03478.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.17
# Image frame_03479.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.44
# Image frame_03480.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.46
# Image frame_03481.jpg: Most similar pair is between 2_frames and 3_frames with similarity 0.55
# Image frame_03482.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.49
# Image frame_03483.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.49
# Image frame_03484.jpg: Most similar pair is between 1_frames and 2_frames with similarity 0.49
# Image frame_03485.jpg: Most similar pair is between 1_frames and 3_frames with similarity 0.54
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 30
#      27 img = Image.open(img_path)
#      29 # 얼굴 검출 및 임베딩 생성
# ---> 30 boxes, probs = mtcnn.detect(img)
#      31 if boxes is not None:
#      32     faces = mtcnn(img)
#
# File C:\Anaconda3\Lib\site-packages\facenet_pytorch\models\mtcnn.py:313, in MTCNN.detect(self, img, landmarks)
#     273 """Detect all faces in PIL image and return bounding boxes and optional facial landmarks.
#     274
#     275 This method is used by the forward method and is also useful for face detection tasks
#    (...)
#     309 >>> img_draw.save('annotated_faces.png')
#     310 """
#     312 with torch.no_grad():
# --> 313     batch_boxes, batch_points = detect_face(
#     314         img, self.min_face_size,
#     315         self.pnet, self.rnet, self.onet,
#     316         self.thresholds, self.factor,
#     317         self.device
#     318     )
#     320 boxes, probs, points = [], [], []
#     321 for box, point in zip(batch_boxes, batch_points):
#
# File C:\Anaconda3\Lib\site-packages\facenet_pytorch\models\utils\detect_face.py:71, in detect_face(imgs, minsize, pnet, rnet, onet, threshold, factor, device)
#      69 offset = 0
#      70 for scale in scales:
# ---> 71     im_data = imresample(imgs, (int(h * scale + 1), int(w * scale + 1)))
#      72     im_data = (im_data - 127.5) * 0.0078125
#      73     reg, probs = pnet(im_data)
#
# File C:\Anaconda3\Lib\site-packages\facenet_pytorch\models\utils\detect_face.py:305, in imresample(img, sz)
#     304 def imresample(img, sz):
# --> 305     im_data = interpolate(img, size=sz, mode="area")
#     306     return im_data
#
# File C:\Anaconda3\Lib\site-packages\torch\nn\functional.py:4017, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4015 if input.dim() == 4 and mode == "area":
#    4016     assert output_size is not None
# -> 4017     return adaptive_avg_pool2d(input, output_size)
#    4018 if input.dim() == 5 and mode == "area":
#    4019     assert output_size is not None
#
# File C:\Anaconda3\Lib\site-packages\torch\nn\functional.py:1233, in adaptive_avg_pool2d(input, output_size)
#    1231     return handle_torch_function(adaptive_avg_pool2d, (input,), input, output_size)
#    1232 _output_size = _list_with_default(output_size, input.size())
# -> 1233 return torch._C._nn.adaptive_avg_pool2d(input, _output_size)
#
# KeyboardInterrupt:
